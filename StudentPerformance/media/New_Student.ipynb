# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the data
name = pd.read_csv("xAPI_Edu_Data.csv")
name.head(100)
# Out:
#    gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# ..    ...         ...          ...         ...     ...       ...   ...
# 95      F          KW       KuwaIT  lowerlevel    G-02         B    IT
# 96      F          KW       KuwaIT  lowerlevel    G-02         C    IT
# 97      F          KW       KuwaIT  lowerlevel    G-02         B    IT
# 98      F          KW       KuwaIT  lowerlevel    G-02         C    IT
# 99      M          KW       KuwaIT  lowerlevel    G-02         B    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
name.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
name.drop(['NationalITy', 'PlaceofBirth', 'StageID'],axis=1)
# Out:
#     gender GradeID SectionID      Topic Semester Relation  raisedhands  \
# 0        M    G-04         A         IT        F   Father           15
# 1        M    G-04         A         IT        F   Father           20
# 2        M    G-04         A         IT        F   Father           10
# 3        M    G-04         A         IT        F   Father           30
# 4        M    G-04         A         IT        F   Father           40
# ..     ...     ...       ...        ...      ...      ...          ...
# 475      F    G-08         A  Chemistry        S   Father            5
# 476      F    G-08         A    Geology        F   Father           50
# 477      F    G-08         A    Geology        S   Father           55
# 478      F    G-08         A    History        F   Father           30
# 479      F    G-08         A    History        S   Father           35
#
#      VisITedResources  AnnouncementsView  Discussion ParentAnsweringSurvey  \
# ...

# %%
df = name.drop(['NationalITy', 'PlaceofBirth','SectionID', 'Topic', 'Semester', 'Relation',],axis=1)
df
# Out:
#     gender       StageID GradeID  raisedhands  VisITedResources  \
# 0        M    lowerlevel    G-04           15                16
# 1        M    lowerlevel    G-04           20                20
# 2        M    lowerlevel    G-04           10                 7
# 3        M    lowerlevel    G-04           30                25
# 4        M    lowerlevel    G-04           40                50
# ..     ...           ...     ...          ...               ...
# 475      F  MiddleSchool    G-08            5                 4
# 476      F  MiddleSchool    G-08           50                77
# 477      F  MiddleSchool    G-08           55                74
# 478      F  MiddleSchool    G-08           30                17
# 479      F  MiddleSchool    G-08           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# ...

# %%
df.isnull().sum()
# Out:
# gender                      0
# StageID                     0
# GradeID                     0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df
# Out:
#     gender       StageID GradeID  raisedhands  VisITedResources  \
# 0        M    lowerlevel    G-04           15                16
# 1        M    lowerlevel    G-04           20                20
# 2        M    lowerlevel    G-04           10                 7
# 3        M    lowerlevel    G-04           30                25
# 4        M    lowerlevel    G-04           40                50
# ..     ...           ...     ...          ...               ...
# 475      F  MiddleSchool    G-08            5                 4
# 476      F  MiddleSchool    G-08           50                77
# 477      F  MiddleSchool    G-08           55                74
# 478      F  MiddleSchool    G-08           30                17
# 479      F  MiddleSchool    G-08           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# ...

# %%
#df['Education'].replace(['Under-Graduate', 'Diploma '],
                        #[0, 1], inplace=True)

#df = df['ParentschoolSatisfaction'].replace(['No','Yes'],[0,1],inplace=True)
#df

# %%
# df['Education'].replace(['Under-Graduate', 'Diploma'], [0, 1], inplace=True)

# %%
df.corr()
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.691572           0.643918
# VisITedResources      0.691572          1.000000           0.594500
# AnnouncementsView     0.643918          0.594500           1.000000
# Discussion            0.339386          0.243292           0.417290
#
#                    Discussion
# raisedhands          0.339386
# VisITedResources     0.243292
# AnnouncementsView    0.417290
# Discussion           1.000000

# %% [markdown]
# # MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df
# Out:
#     gender       StageID GradeID  raisedhands  VisITedResources  \
# 0        M    lowerlevel    G-04           15                16
# 1        M    lowerlevel    G-04           20                20
# 2        M    lowerlevel    G-04           10                 7
# 3        M    lowerlevel    G-04           30                25
# 4        M    lowerlevel    G-04           40                50
# ..     ...           ...     ...          ...               ...
# 475      F  MiddleSchool    G-08            5                 4
# 476      F  MiddleSchool    G-08           50                77
# 477      F  MiddleSchool    G-08           55                74
# 478      F  MiddleSchool    G-08           30                17
# 479      F  MiddleSchool    G-08           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# ...

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25, random_state=27)

# %%
x
# Out:
# array([['M', 'lowerlevel', 'G-04', ..., 'Yes', 'Good', 'Under-7'],
#        ['M', 'lowerlevel', 'G-04', ..., 'Yes', 'Good', 'Under-7'],
#        ['M', 'lowerlevel', 'G-04', ..., 'No', 'Bad', 'Above-7'],
#        ...,
#        ['F', 'MiddleSchool', 'G-08', ..., 'No', 'Bad', 'Under-7'],
#        ['F', 'MiddleSchool', 'G-08', ..., 'No', 'Bad', 'Above-7'],
#        ['F', 'MiddleSchool', 'G-08', ..., 'No', 'Bad', 'Above-7']],
#       dtype=object)

# %%
y_train
# Out:
# array(['H', 'H', 'H', 'M', 'H', 'M', 'H', 'M', 'H', 'M', 'L', 'M', 'L',
#        'L', 'L', 'L', 'M', 'H', 'M', 'H', 'H', 'L', 'M', 'M', 'H', 'L',
#        'M', 'M', 'H', 'M', 'L', 'H', 'M', 'M', 'H', 'H', 'M', 'H', 'M',
#        'L', 'H', 'H', 'H', 'M', 'L', 'L', 'M', 'M', 'M', 'M', 'M', 'L',
#        'M', 'H', 'M', 'H', 'H', 'H', 'M', 'M', 'M', 'H', 'H', 'M', 'L',
#        'L', 'M', 'M', 'H', 'H', 'H', 'M', 'M', 'M', 'H', 'M', 'L', 'M',
#        'H', 'M', 'M', 'M', 'H', 'H', 'M', 'M', 'M', 'M', 'H', 'M', 'H',
#        'M', 'H', 'M', 'H', 'M', 'H', 'L', 'L', 'L', 'H', 'L', 'M', 'L',
#        'L', 'L', 'H', 'H', 'M', 'H', 'M', 'L', 'H', 'L', 'H', 'L', 'M',
#        'M', 'L', 'H', 'L', 'L', 'L', 'M', 'L', 'M', 'H', 'H', 'L', 'M',
#        'M', 'L', 'H', 'M', 'H', 'M', 'M', 'M', 'L', 'L', 'H', 'M', 'L',
#        'H', 'M', 'L', 'M', 'L', 'L', 'M', 'H', 'L', 'L', 'H', 'M', 'L',
#        'M', 'M', 'L', 'H', 'H', 'M', 'M', 'M', 'L', 'L', 'H', 'M', 'H',
# ...

# %%
y = df['Class']
x = df.drop(['Class'], axis=1)
x=pd.get_dummies(x)
y=pd.get_dummies(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25, random_state=27)

# %%
x_train
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion  gender_F  \
# 403           65                89                 64          82         0
# 368           98                88                 60          31         1
# 418           88                90                 76          81         0
# 337           75                80                 15          20         1
# 160           82                89                 58          50         1
# ..           ...               ...                ...         ...       ...
# 312           55                79                 44          43         1
# 31             4                 5                 40          16         0
# 328           80                77                 63          83         1
# 184           10                35                 30          13         0
# 19            70                50                 40          99         0
#
# ...

# %%
x_test
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion  gender_F  \
# 249           65                86                 62          40         0
# 453           29                78                 40          12         1
# 195           15                43                 42          33         0
# 383           70                83                 29          33         0
# 223           72                83                 12          90         0
# ..           ...               ...                ...         ...       ...
# 260           10                17                 12          14         0
# 310           25                29                 34          33         0
# 363           80                88                 51          39         0
# 413           79                72                 79          83         0
# 20            60                60                 33          90         1
#
# ...

# %%
clf = MLPClassifier(#hidden_layer_sizes=(100,100,100), max_iter=500, alpha=0.0001,
                     #solver='sgd',
                    verbose=10,  random_state=21)#,tol=0.000000001)

# %%
y_train
# Out:
#      H  L  M
# 403  1  0  0
# 368  1  0  0
# 418  1  0  0
# 337  0  0  1
# 160  1  0  0
# ..  .. .. ..
# 312  1  0  0
# 31   0  1  0
# 328  0  0  1
# 184  0  1  0
# 19   1  0  0
#
# [360 rows x 3 columns]

# %%
y_test
# Out:
#      H  L  M
# 249  0  0  1
# 453  0  0  1
# 195  0  0  1
# 383  1  0  0
# 223  1  0  0
# ..  .. .. ..
# 260  0  1  0
# 310  0  0  1
# 363  1  0  0
# 413  0  0  1
# 20   0  0  1
#
# [120 rows x 3 columns]

# %%
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
# Out:
# Iteration 1, loss = 12.27373442
# Iteration 2, loss = 9.24552472
# Iteration 3, loss = 6.46408258
# Iteration 4, loss = 4.53490519
# Iteration 5, loss = 3.74540444
# Iteration 6, loss = 4.02896850
# Iteration 7, loss = 4.38722056
# Iteration 8, loss = 4.36329022
# Iteration 9, loss = 3.98018724
# Iteration 10, loss = 3.39961978
# Iteration 11, loss = 2.84245150
# Iteration 12, loss = 2.60206260
# Iteration 13, loss = 2.66047279
# Iteration 14, loss = 2.72978816
# Iteration 15, loss = 2.60715751
# Iteration 16, loss = 2.35072673
# Iteration 17, loss = 2.12739778
# Iteration 18, loss = 2.07931551
# Iteration 19, loss = 2.10356728
# Iteration 20, loss = 2.05250173
# Iteration 21, loss = 1.92619898
# Iteration 22, loss = 1.83764765
# Iteration 23, loss = 1.81127430
# Iteration 24, loss = 1.80605887
# Iteration 25, loss = 1.75714166
# Iteration 26, loss = 1.70571605
# Iteration 27, loss = 1.68466423
# Iteration 28, loss = 1.67283337
# Iteration 29, loss = 1.64703525
# ...

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.575

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67        31
#            1       0.77      0.83      0.80        29
#            2       0.72      0.55      0.62        60
#
#    micro avg       0.71      0.66      0.68       120
#    macro avg       0.71      0.70      0.70       120
# weighted avg       0.71      0.66      0.68       120
#  samples avg       0.62      0.66      0.63       120
# c:\users\ramu maloth\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test.values.argmax(axis=1), y_pred.argmax(axis=1))
cm
# Out:
# array([[24,  0,  7],
#        [ 3, 24,  2],
#        [26,  7, 27]], dtype=int64)

# %%
sns.heatmap(cm, center=True,annot = True)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
y = df['Class']
x = df.drop(['Class'], axis=1)
x=pd.get_dummies(x)
y=pd.get_dummies(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25, random_state=27)

# %%
# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 100)

# %%
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred,average='weighted'))
print(recall_score(y_test, y_pred,average='weighted'))
print(f1_score(y_test, y_pred,average='weighted'))
# Out:
# 0.75
# 0.7811868686868687
# 0.75
# 0.764776246219763

# %%
cm = confusion_matrix(y_test.values.argmax(axis=1), y_pred.argmax(axis=1))
cm
# Out:
# array([[22,  0,  9],
#        [ 0, 26,  3],
#        [13,  4, 43]], dtype=int64)

# %%
sns.heatmap(cm, center=True,annot = True)
plt.show()

# %% [markdown]
# # C 4.5

# %%
# pip install chefboost

# %%
from chefboost import Chefboost as chef

# %%
df
# Out:
#     gender       StageID GradeID  raisedhands  VisITedResources  \
# 0        M    lowerlevel    G-04           15                16
# 1        M    lowerlevel    G-04           20                20
# 2        M    lowerlevel    G-04           10                 7
# 3        M    lowerlevel    G-04           30                25
# 4        M    lowerlevel    G-04           40                50
# ..     ...           ...     ...          ...               ...
# 475      F  MiddleSchool    G-08            5                 4
# 476      F  MiddleSchool    G-08           50                77
# 477      F  MiddleSchool    G-08           55                74
# 478      F  MiddleSchool    G-08           30                17
# 479      F  MiddleSchool    G-08           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# ...

# %%
from chefboost import Chefboost as chef
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix

# %%
from chefboost import Chefboost as chef
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# %%
X = df.iloc[:,0:10].values
y = df.iloc[:,-1].values

# %%
X
# Out:
# array([['M', 'lowerlevel', 'G-04', ..., 'Yes', 'Good', 'Under-7'],
#        ['M', 'lowerlevel', 'G-04', ..., 'Yes', 'Good', 'Under-7'],
#        ['M', 'lowerlevel', 'G-04', ..., 'No', 'Bad', 'Above-7'],
#        ...,
#        ['F', 'MiddleSchool', 'G-08', ..., 'No', 'Bad', 'Under-7'],
#        ['F', 'MiddleSchool', 'G-08', ..., 'No', 'Bad', 'Above-7'],
#        ['F', 'MiddleSchool', 'G-08', ..., 'No', 'Bad', 'Above-7']],
#       dtype=object)

# %%
y
# Out:
# array(['M', 'M', 'L', 'L', 'M', 'M', 'L', 'M', 'M', 'M', 'H', 'M', 'L',
#        'L', 'H', 'M', 'M', 'M', 'M', 'H', 'M', 'M', 'M', 'L', 'L', 'L',
#        'M', 'L', 'M', 'M', 'H', 'L', 'L', 'L', 'L', 'L', 'L', 'M', 'L',
#        'M', 'L', 'M', 'L', 'M', 'M', 'L', 'L', 'H', 'H', 'M', 'L', 'L',
#        'M', 'H', 'L', 'L', 'L', 'L', 'M', 'M', 'L', 'M', 'H', 'M', 'L',
#        'L', 'M', 'H', 'H', 'M', 'L', 'M', 'L', 'M', 'L', 'M', 'M', 'M',
#        'L', 'H', 'L', 'L', 'L', 'M', 'H', 'L', 'H', 'L', 'L', 'L', 'L',
#        'H', 'H', 'H', 'L', 'H', 'H', 'M', 'M', 'M', 'M', 'H', 'L', 'L',
#        'M', 'L', 'M', 'H', 'M', 'M', 'H', 'M', 'L', 'L', 'L', 'L', 'M',
#        'H', 'M', 'M', 'M', 'L', 'M', 'M', 'L', 'L', 'M', 'L', 'L', 'L',
#        'L', 'M', 'L', 'L', 'H', 'H', 'H', 'M', 'H', 'M', 'L', 'L', 'M',
#        'H', 'L', 'M', 'H', 'M', 'M', 'H', 'H', 'M', 'H', 'L', 'M', 'H',
#        'M', 'M', 'L', 'M', 'H', 'M', 'H', 'M', 'M', 'H', 'M', 'H', 'H',
# ...

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=42)#,stratify='y')

# %%
# X1_train=pd.get_dummies(X_train)

# %%
# X1_train=pd.get_dummies(X_train)
# y1_train=pd.get_dummies(y_train)
# X1_test=pd.get_dummies(X_test)
# y1_test=pd.get_dummies(y_test)
# #import pandas
# import pandas as pd
 
# # read csv
# # df = pd.read_csv('salary.csv')
 
# # get the dummies and store it in a variable
# dummies = pd.get_dummies(df.Education)
 
# # Concatenate the dummies to original dataframe
# merged = pd.concat([df, dummies], axis='columns')
 
# # drop the values
# merged.drop(['Education', 'Under-Graduate'], axis='columns')
 
# # print the dataframe
# print(merged)

# %%
# X1_train

# %%
X_test
# Out:
# array([['F', 'MiddleSchool', 'G-07', ..., 'Yes', 'Bad', 'Above-7'],
#        ['F', 'MiddleSchool', 'G-07', ..., 'No', 'Good', 'Above-7'],
#        ['M', 'MiddleSchool', 'G-07', ..., 'Yes', 'Good', 'Under-7'],
#        ...,
#        ['F', 'lowerlevel', 'G-04', ..., 'No', 'Bad', 'Above-7'],
#        ['M', 'MiddleSchool', 'G-07', ..., 'No', 'Good', 'Under-7'],
#        ['M', 'MiddleSchool', 'G-07', ..., 'Yes', 'Good', 'Above-7']],
#       dtype=object)

# %%
y_train
# Out:
# array(['M', 'M', 'M', 'H', 'L', 'H', 'L', 'L', 'M', 'M', 'L', 'L', 'L',
#        'L', 'L', 'L', 'M', 'M', 'M', 'L', 'M', 'H', 'M', 'L', 'M', 'L',
#        'H', 'H', 'H', 'M', 'H', 'H', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'L', 'H', 'M', 'L', 'M', 'H', 'M', 'H', 'M', 'L', 'L', 'M',
#        'H', 'M', 'H', 'H', 'M', 'L', 'M', 'L', 'M', 'H', 'H', 'H', 'M',
#        'M', 'H', 'H', 'M', 'H', 'L', 'H', 'H', 'L', 'M', 'M', 'M', 'L',
#        'M', 'M', 'M', 'M', 'H', 'M', 'L', 'H', 'M', 'L', 'M', 'H', 'H',
#        'M', 'M', 'M', 'L', 'L', 'H', 'M', 'L', 'H', 'M', 'L', 'L', 'M',
#        'H', 'M', 'L', 'L', 'L', 'H', 'H', 'H', 'M', 'L', 'H', 'H', 'M',
#        'M', 'L', 'H', 'M', 'M', 'M', 'L', 'H', 'H', 'M', 'H', 'M', 'H',
#        'H', 'H', 'H', 'H', 'H', 'M', 'M', 'H', 'M', 'M', 'M', 'H', 'M',
#        'H', 'M', 'M', 'L', 'H', 'L', 'L', 'H', 'H', 'M', 'L', 'H', 'M',
#        'H', 'L', 'H', 'M', 'L', 'M', 'M', 'L', 'M', 'H', 'H', 'H', 'M',
# ...

# %%
y_test
# Out:
# array(['M', 'L', 'H', 'H', 'H', 'L', 'M', 'L', 'M', 'M', 'M', 'H', 'M',
#        'M', 'H', 'H', 'L', 'M', 'L', 'M', 'H', 'H', 'L', 'M', 'M', 'L',
#        'H', 'M', 'L', 'M', 'M', 'M', 'L', 'H', 'M', 'H', 'M', 'L', 'M',
#        'M', 'M', 'H', 'L', 'M', 'M', 'L', 'H', 'M', 'H', 'M', 'M', 'M',
#        'L', 'M', 'M', 'M', 'L', 'H', 'M', 'L', 'M', 'L', 'L', 'M', 'M',
#        'M', 'L', 'H', 'L', 'H', 'M', 'H', 'M', 'M', 'M', 'L', 'M', 'L',
#        'L', 'M', 'H', 'M', 'L', 'H', 'H', 'M', 'M', 'L', 'L', 'M', 'M',
#        'M', 'M', 'M', 'L', 'H', 'L', 'H', 'M', 'L', 'M', 'L', 'L', 'H',
#        'M', 'M', 'H', 'M', 'M', 'L', 'M', 'M', 'M', 'H', 'M', 'L', 'H',
#        'L', 'H', 'L'], dtype=object)

# %%
config = {'algorithm': 'C4.5'}
model=chef.fit(df, config = config,target_label="Class")
# Out:
# [INFO]:  2 CPU cores will be allocated in parallel running
# C4.5  tree is going to be built...
# -------------------------
# finished in  97.10199475288391  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  80.20833333333333 % on  480  instances
# Labels:  ['M' 'L' 'H']
# Confusion matrix:  [[153, 9, 27], [8, 117, 0], [50, 1, 115]]
# Decision  M  => Accuray:  80.4167 %, Precision:  80.9524 %, Recall:  72.5118 %, F1:  76.5 %
# Decision  L  => Accuray:  96.25 %, Precision:  93.6 %, Recall:  92.126 %, F1:  92.8572 %
# Decision  H  => Accuray:  83.75 %, Precision:  69.2771 %, Recall:  80.9859 %, F1:  74.6753 %

# %%
model.get('trees')
# Out:
# [<module 'outputs/rules/rules' from 'C:\\Users\\Ramu Maloth\\Documents\\Jupyter Workspace\\Student Performance\\outputs/rules/rules.py'>]

# %%
#cm = confusion_matrix(X_test.values.argmax(axis=1), X_test.argmax(axis=1))
#cm
y_test
# Out:
# array(['M', 'L', 'H', 'H', 'H', 'L', 'M', 'L', 'M', 'M', 'M', 'H', 'M',
#        'M', 'H', 'H', 'L', 'M', 'L', 'M', 'H', 'H', 'L', 'M', 'M', 'L',
#        'H', 'M', 'L', 'M', 'M', 'M', 'L', 'H', 'M', 'H', 'M', 'L', 'M',
#        'M', 'M', 'H', 'L', 'M', 'M', 'L', 'H', 'M', 'H', 'M', 'M', 'M',
#        'L', 'M', 'M', 'M', 'L', 'H', 'M', 'L', 'M', 'L', 'L', 'M', 'M',
#        'M', 'L', 'H', 'L', 'H', 'M', 'H', 'M', 'M', 'M', 'L', 'M', 'L',
#        'L', 'M', 'H', 'M', 'L', 'H', 'H', 'M', 'M', 'L', 'L', 'M', 'M',
#        'M', 'M', 'M', 'L', 'H', 'L', 'H', 'M', 'L', 'M', 'L', 'L', 'H',
#        'M', 'M', 'H', 'M', 'M', 'L', 'M', 'M', 'M', 'H', 'M', 'L', 'H',
#        'L', 'H', 'L'], dtype=object)

# %%
prediction = chef.predict(model, y_test)
prediction
# Out:
# 'L'

# %%
y_pr = []
for row in range(len(X_test)):
    pred = chef.predict(model,X_test[row])
    y_pr.append(pred)
    # print(pred)

# %%
accuracy_score(y_test,y_pr)
# Out:
# 0.8416666666666667

# %%
precision_score(y_test,y_pr,average='macro')
# Out:
# 0.8327605570530099

# %%
recall_score(y_test,y_pr,average='macro')
# Out:
# 0.8498019897614218

# %%
f1_score(y_test,y_pr,average='macro')
# Out:
# 0.8395613004308657

# %%
model.values()
# Out:
# dict_values([[<module 'outputs/rules/rules' from 'C:\\Users\\Ramu Maloth\\Documents\\Jupyter Workspace\\Student Performance\\outputs/rules/rules.py'>], [], {'algorithm': 'C4.5', 'enableRandomForest': False, 'num_of_trees': 5, 'enableMultitasking': False, 'enableGBM': False, 'epochs': 10, 'learning_rate': 1, 'max_depth': 3, 'enableAdaboost': False, 'num_of_weak_classifier': 4, 'enableParallelism': True, 'num_cores': 2}, [['raisedhands', None], ['VisITedResources', None], ['AnnouncementsView', None], ['Discussion', None]]])

# %%
evaluation = chef.evaluate(model, X_test)#, task="test")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 evaluation = chef.evaluate(model, X_test)
#
# File c:\users\ramu maloth\appdata\local\programs\python\python38\lib\site-packages\chefboost\Chefboost.py:541, in evaluate(model, df, target_label, task)
#     538 	df = df.rename(columns = {target_label: 'Decision'})
#     540 #if target is not the last column
# --> 541 if df.columns[-1] != 'Decision':
#     542 	new_column_order = df.columns.drop('Decision').tolist() + ['Decision']
#     543 	print(new_column_order)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
'''from chefboost import Chefboost as chef
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd


X = pd.read_csv("../data/adult.csv")
X = X.rename(columns={"income": "Decision"})


X_train, X_test = train_test_split(X, test_size=0.2, random_state=42, stratify=X["Decision"])

config = {'algorithm': 'CART'}
model = chef.fit(X_train, config = config)


prediction = chef.predict(model, X_test.iloc[0])

evaluation = chef.evaluate(model, X_test, task="test")'''

# %%
config = {'algorithm':'C4.5'}

# %%
#y_pred = chef.fit(df,config,target_label = 'Class')
#y_pred

# %%
type(y_pred)

# %%
y_pred.keys()

# %%
y_pred

# %%
print(y_pred)

# %%
y_pred.values()

# %%
#decision_rules = y_pred["trees"][0].__dict__["__spec__"].origin #dynamic way
#chef.feature_importance(decision_rules)

# %%
df

# %%
feature = ['M','lowerlevel','G-04',15,16,2,20,'Yes','Good','Under-7']
prediction = chef.predict(y_pred,feature)

# %%
prediction

# %%
chef.save_model(model, "model.pkl")

# %%
model = chef.load_model("model.pkl")
prediction = chef.predict(model, ['M','lowerlevel','G',4,20,20,3,25,'Yes','Good','Under-7'])
prediction

# %%
from sklearn.metrics import classification_report
print(classification_report(X_test, prediction))

# %%
pip list

# %%
y_pr = []
for row in range(len(x_test)):
    pred = chef.predict(obj,x_test.iloc[row])
    y_pr.append(pred)
    print(pred)

# %% [markdown]
# # RBF

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#     gender       StageID GradeID  raisedhands  VisITedResources  \
# 0        M    lowerlevel    G-04           15                16
# 1        M    lowerlevel    G-04           20                20
# 2        M    lowerlevel    G-04           10                 7
# 3        M    lowerlevel    G-04           30                25
# 4        M    lowerlevel    G-04           40                50
# ..     ...           ...     ...          ...               ...
# 475      F  MiddleSchool    G-08            5                 4
# 476      F  MiddleSchool    G-08           50                77
# 477      F  MiddleSchool    G-08           55                74
# 478      F  MiddleSchool    G-08           30                17
# 479      F  MiddleSchool    G-08           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# ...

# %%
y = df['Class']
x = df.drop(['Class'], axis=1)
x=pd.get_dummies(x)
#y=np.reshape(-1,1)
y=pd.get_dummies(y)
#y = np.sin(y) + np.random.normal()

# %%
X = df.iloc[:,0:12]
y = df.iloc[:,10:11]
y = pd.get_dummies(y)

# %%
X=np.ravel(X)
X.shape
# Out:
# (5280,)

# %%
y=np.ravel(y)
y.shape
# Out:
# (1440,)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.feature_extraction.text import CountVectorizer

# %%
X_train, x_test, y_train, y_test = train_test_split(X,y, test_size= 0.25, random_state=27)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 X_train, x_test, y_train, y_test = train_test_split(X,y, test_size= 0.25, random_state=27)
#
# File c:\users\ramu maloth\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_split.py:2445, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2442 if n_arrays == 0:
#    2443     raise ValueError("At least one array required as input")
# -> 2445 arrays = indexable(*arrays)
#    2447 n_samples = _num_samples(arrays[0])
#    2448 n_train, n_test = _validate_shuffle_split(
#    2449     n_samples, test_size, train_size, default_test_size=0.25
#    2450 )
#
# File c:\users\ramu maloth\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:433, in indexable(*iterables)
# ...

# %%
X_train.shape

# %%
svm_rbf = SVC(kernel='rbf')
svm_rbf.fit(X_train,y_train)

# %%
y_train.shape
y_train = np.ravel(y_train)
y_train
y_train.shape

# %%
svm_rbf = SVC(kernel='rbf')
svm_rbf.fit(X_train,y_train)

# %%
X_train.shape
X_train = np.ravel(y_train)
X_train
X_train.shape

# %%
y_test.shape

# %%
svm_rbf = SVC(kernel='rbf')
svm_rbf.fit(X_train,y_train)

# %%
# make predictions
y_train_pred = svm_rbf.predict(X_train)
y_test_pred = svm_rbf.predict(X_test)

# %%
#Training set performance
svm_rbf_train_accuracy = accuracy_score(y_train, y_train_pred)#calculate Accuracy
svm_rbf_train_f1 = f1_score(y_train, y_train_pred, average = 'weighted')# Calculate F1-score

#test set performance
svm_rbf_test_accuracy = accuracy_score(y_test,y_test_pred)#Calculate Accuracy
svm_rbf_test_f1 = f1_score(y_test,y_test_pred,average = 'weighted')

# %%
print('Model Performancefor Traaining set')
print('-Accuracy: %s' % svm_rbf_train_accuracy)
print('-F1 score: %s' % svm_rbf_train_f1)
